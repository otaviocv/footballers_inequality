# %% [markdown]
# # Sample connection with the db

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import psycopg2
# Out:
# /home/otaviocv/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ## Connection

# %%
conn = psycopg2.connect(user='docker', password='docker', host='localhost', port=5555)

# %%
cursor = conn.cursor()

# %%
cursor.fetchone()

# %%
pd.read_sql('SELECT * FROM catalog', conn)
# Out:
#     id                                                url          date_added  \
# 0    1  https://www.transfermarkt.co.uk/wettbewerbe/af... 2018-11-22 00:26:50
# 1    2  https://www.transfermarkt.co.uk/wettbewerbe/am... 2018-11-22 00:26:50
# 2    3  https://www.transfermarkt.co.uk/wettbewerbe/am... 2018-11-22 00:26:50
# 3    4  https://www.transfermarkt.co.uk/wettbewerbe/as... 2018-11-22 00:26:50
# 4    5  https://www.transfermarkt.co.uk/wettbewerbe/as... 2018-11-22 00:26:50
# 5    6  https://www.transfermarkt.co.uk/wettbewerbe/as... 2018-11-22 00:26:50
# 6    7  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 7    8  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 8    9  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 9   10  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 10  11  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 11  12  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 12  13  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 13  14  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 14  15  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 15  16  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 16  17  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 17  18  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 18  19  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 19  20  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 20  21  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
# 21  22  https://www.transfermarkt.co.uk/wettbewerbe/eu... 2018-11-22 00:26:50
#
#    date_updated status page_type
# 0          None    new      area
# 1          None    new      area
# 2          None    new      area
# 3          None    new      area
# 4          None    new      area
# 5          None    new      area
# 6          None    new      area
# 7          None    new      area
# 8          None    new      area
# 9          None    new      area
# 10         None    new      area
# 11         None    new      area
# 12         None    new      area
# 13         None    new      area
# 14         None    new      area
# 15         None    new      area
# 16         None    new      area
# 17         None    new      area
# 18         None    new      area
# 19         None    new      area
# 20         None    new      area
# 21         None    new      area

# %%
pd.read_sql('SELECT * FROM leagues', conn)
# Out:
# Empty DataFrame
# Columns: [id, league, country, clubs, players, avg_age, foreing_players, total_value]
# Index: []
