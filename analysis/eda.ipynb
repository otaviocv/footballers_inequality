# %% [markdown]
# # Sample connection with the db

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import psycopg2
# Out:
# /home/otaviocv/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ## Connection

# %%
conn = psycopg2.connect(user='docker', password='docker', host='localhost', port=5555)

# %%
cursor = conn.cursor()

# %%
pd.read_sql('SELECT * FROM leagues', conn)
# Out:
#       id                                  league        country  clubs  \
# 0      1                   Botola Maroc Telecom         Morocco     16
# 1      2                        ABSA Premiership   South Africa     16
# 2      3                 Egyptian Premier League          Egypt     18
# 3      4                 Ligue Professionnelle 1        Tunisia     14
# 4      5                 Ligue Professionnelle 1        Algeria     16
# 5      6                          Premier League          Ghana     16
# 6      7                             Nedbank Cup   South Africa     32
# 7      8                               Egypt Cup          Egypt     32
# 8      9                         Telkom Knockout   South Africa     16
# 9     10                            Tunisian Cup        Tunisia     32
# 10    11                                    MTN8   South Africa      8
# 11    12           Campeonato Brasileiro Série A         Brazil     20
# 12    13                        Primera División      Argentina     26
# 13    14                        Liga MX Apertura         Mexico     18
# 14    15                     Major League Soccer  United States     23
# 15    16                       Liguilla Apertura         Mexico      8
# 16    17                          Liga Águila II       Colombia     20
# 17    18                           Liga Águila I       Colombia     20
# 18    19                   Serie A Primera Etapa        Ecuador     12
# 19    20                   Serie A Segunda Etapa        Ecuador     12
# 20    21  Campeonato Scotiabank Primera División          Chile     16
# 21    22               Fase Final Liga Águila II       Colombia      8
# 22    23                Fase Final Liga Águila I       Colombia      8
# 23    24               Primera División Apertura        Uruguay     15
# 24    25               Primera Division Clausura        Uruguay     15
# 25    26                        Torneo de Verano           Peru     16
# 26    27                         Torneo Clausura      Venezuela     18
# 27    28               Primera División Apertura     Costa Rica     12
# 28    29               Primera División Clausura     Costa Rica     12
# 29    30      Primera División Apertura Play-Off     Costa Rica      4
# ..   ...                                     ...            ...    ...
# 452  453                     U19 Cup Netherlands    Netherlands     25
# 453  454              Beloften Preliminary Round    Netherlands     21
# 454  455                           U21 Süper Lig         Turkey     18
# 455  456                           Reserveligaen        Denmark     18
# 456  457           Folksam U21 Allsvenskan Södra         Sweden      8
# 457  458           Folksam U21 Allsvenskan Norra         Sweden      7
# 458  459           Gibraltar Intermediate League      Gibraltar     10
# 459  460                    Coppa Italia Serie C          Italy     59
# 460  461                           Challenge Cup       Scotland     71
# 461  462                  Bayerischer Toto-Pokal        Germany     64
# 462  463     Niedersachsenpokal (3. und 4. Liga)        Germany     12
# 463  464                          Westfalenpokal        Germany     64
# 464  465                             Hessenpokal        Germany     40
# 465  466            Wernesgrüner Pokal - Sachsen        Germany     97
# 466  467            RevierSport-Niederrheinpokal        Germany     64
# 467  468                        Mittelrheinpokal        Germany     32
# 468  469                      DB REGIO-WFV-POKAL        Germany    121
# 469  470            Köstritzer Pokal – Thüringen        Germany     62
# 470  471         Bitburger Verbandspokal Südwest        Germany    145
# 471  472                        Brandenburgpokal        Germany     64
# 472  473                  AOK-Landespokal Berlin        Germany    128
# 473  474                           Saarlandpokal        Germany     64
# 474  475                    Sachsen-Anhalt-Pokal        Germany      8
# 475  476      Landespokal Mecklenburg-Vorpommern        Germany    112
# 476  477                              SHFV-Pokal        Germany     16
# 477  478                            ODDSET-Pokal        Germany    202
# 478  479                          Rheinlandpokal        Germany    105
# 479  480                     Bremer Pokal (beta)        Germany     55
# 480  481           Niedersachsenpokal (Amateure)        Germany     19
# 481  482                      SBFV-Rothaus-Pokal        Germany     11
#
#      players  avg_age  foreing_players  total_market_value
# 0        475     26.8             14.5         129610000.0
# 1        547     27.1             19.7         123140000.0
# 2        537     26.5             12.3         120600000.0
# 3        437     25.4             12.8          80150000.0
# 4        434     25.7              6.2          79250000.0
# 5        453     23.3              4.9          19490000.0
# 6       1180     26.7             14.1         146070000.0
# 7        712     27.1             10.4         127460000.0
# 8        547     27.1             19.7         123140000.0
# 9        669     26.2              8.5          87120000.0
# 10       263     26.8             21.7          78030000.0
# 11       797     26.0              8.3         746620000.0
# 12       657     27.1             14.2         661500000.0
# 13       496     26.5             36.9         551250000.0
# 14       672     26.5             54.9         467480000.0
# 15       219     26.5             38.4         317750000.0
# 16       649     26.0             11.1         240840000.0
# 17       649     26.0             11.1         240840000.0
# 18       311     26.4             15.8         125100000.0
# 19       311     26.4             15.8         125100000.0
# 20       476     25.9             22.7         123180000.0
# 21       238     26.9             11.8         111890000.0
# 22       267     25.4             10.5         106490000.0
# 23       447     25.9              7.4          95380000.0
# 24       447     25.9              7.4          95380000.0
# 25       471     26.4             15.9          79560000.0
# 26       488     25.6             11.7          75670000.0
# 27       338     26.2             12.4          44350000.0
# 28       338     26.2             12.4          44350000.0
# 29       114     27.2             12.3          18860000.0
# ..       ...      ...              ...                 ...
# 452      552     18.0             10.3            765000.0
# 453      269     20.2             16.4          12440000.0
# 454      491     19.3              5.3           7650000.0
# 455       45     21.9             20.0           4910000.0
# 456       12     19.9              8.3           1260000.0
# 457       11     20.1              0.0            225000.0
# 458      131     20.6             14.5                 0.0
# 459     1568     24.4             15.7         197510000.0
# 460     1211     24.8             29.6          46190000.0
# 461     1229     25.0             15.9          36950000.0
# 462      305     24.3             19.0          28040000.0
# 463     1357     25.5             16.9          19490000.0
# 464      830     25.7             19.2          16560000.0
# 465     2249     27.9              9.4          15550000.0
# 466     1644     25.5             20.2          14870000.0
# 467      787     25.0             21.7          13210000.0
# 468     1666     26.0             20.8          12130000.0
# 469     1286     26.3              8.6          11300000.0
# 470     2402     26.2             17.2           9200000.0
# 471     1698     26.6             14.3           8260000.0
# 472     3571     26.9             42.3           7940000.0
# 473     1377     25.8             11.5           7670000.0
# 474      183     24.5              8.2           6050000.0
# 475     1392     28.0             10.1           5090000.0
# 476      391     25.3              7.9           4010000.0
# 477     3768     27.5             29.9           1550000.0
# 478     2497     25.8              9.9            248000.0
# 479     1264     26.5             34.3            203000.0
# 480      477     24.9             18.9             23000.0
# 481      217     26.2             24.4             23000.0
#
# [482 rows x 8 columns]

# %%
pd.read_sql('SELECT * FROM leagues', conn)
# Out:
# Empty DataFrame
# Columns: [id, league, country, clubs, players, avg_age, foreing_players, total_value]
# Index: []
